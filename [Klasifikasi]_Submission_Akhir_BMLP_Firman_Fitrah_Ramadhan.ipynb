# %% [markdown]
# # **Penting**
# - Jangan mengubah atau menambahkan cell text yang sudah disediakan, Anda hanya perlu mengerjakan cell code yang sudah disediakan.
# - Pastikan seluruh kriteria memiliki output yang sesuai, karena jika tidak ada output dianggap tidak selesai.
# - Misal, Anda menggunakan df = df.dropna() silakan gunakan df.isnull().sum() sebagai tanda sudah berhasil. Silakan sesuaikan seluruh output dengan perintah yang sudah disediakan.
# - Pastikan Anda melakukan Run All sebelum mengirimkan submission untuk memastikan seluruh cell berjalan dengan baik.
# - Pastikan Anda menggunakan variabel df dari awal sampai akhir dan tidak diperbolehkan mengganti nama variabel tersebut.
# - Hapus simbol pagar (#) pada kode yang bertipe komentar jika Anda menerapkan kriteria tambahan
# - Biarkan simbol pagar (#) jika Anda tidak menerapkan kriteria tambahan
# - Pastikan Anda mengerjakan sesuai section yang sudah diberikan tanpa mengubah judul atau header yang disediakan.

# %% [markdown]
# # **1. Import Library**
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning.

# %%
#Type your code here
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# # **2. Memuat Dataset dari Hasil Clustering**
# Memuat dataset hasil clustering dari file CSV ke dalam variabel DataFrame.

# %%
# Gunakan dataset hasil clustering yang memiliki fitur Target
# Silakan gunakan dataset data_clustering jika tidak menerapkan Interpretasi Hasil Clustering [Advanced]
# Silakan gunakan dataset data_clustering_inverse jika menerapkan Interpretasi Hasil Clustering [Advanced]
df = pd.read_csv('data_clustering_inverse.csv')

# %%
# Tampilkan 5 baris pertama dengan function head.
df.head(50)
# Out:
#    TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0       TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1       TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2       TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3       TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4       TX000005   AC00411              13.45  2023-10-16 17:51:24
# 5       TX000006   AC00393              92.15  2023-04-03 17:15:01
# 6       TX000007   AC00199               7.08  2023-02-15 16:36:48
# 7       TX000008   AC00069             171.42  2023-05-08 17:47:59
# 8       TX000009   AC00135             106.23  2023-03-21 16:59:46
# 9       TX000010   AC00385             815.96  2023-03-31 16:06:57
# 10      TX000011   AC00150              17.78  2023-03-14 16:46:10
# 11      TX000012   AC00459             190.02  2023-02-06 17:30:00
# 12      TX000013   AC00392             494.52  2023-06-07 17:21:28
# 13      TX000014   AC00264             781.76  2023-11-20 16:39:15
# 14      TX000015   AC00085             166.99  2023-02-13 16:53:57
# 15      TX000016   AC00270             465.45  2023-12-12 16:23:31
# 16      TX000017   AC00317             555.80  2023-10-30 16:52:49
# 17      TX000018   AC00359             492.93  2023-12-14 18:32:14
# 18      TX000019   AC00242              18.68  2023-02-21 16:56:50
# 19      TX000020   AC00285              71.48  2023-06-08 18:18:50
# 20      TX000021   AC00002              59.32  2023-02-28 16:36:58
# 21      TX000022   AC00014              85.77  2023-08-11 18:31:31
# 23           Debit     Fort Worth  D000162   191.82.103.198       M083
# 24           Debit        Raleigh  D000036  119.186.154.104       M028
# 25          Credit        Houston  D000671   81.248.235.147       M043
# 26           Debit          Miami  D000046   55.154.161.250       M029
# 27           Debit      Milwaukee  D000310       21.28.32.1       M008
# 28           Debit      Las Vegas  D000232   152.234.65.155       M092
# 29           Debit        Detroit  D000297     33.28.138.82       M043
# 30          Credit          Miami  D000587      35.67.21.23       M091
# 31           Debit      Baltimore  D000282   187.199.178.27       M053
# 32           Debit       New York  D000621   133.67.250.163       M007
# 33           Debit    Los Angeles  D000111   134.140.85.231       M094
# 34          Credit  San Francisco  D000357    92.214.76.157       M002
# 35           Debit        Seattle  D000042    59.145.242.13       M002
# 36           Debit      Milwaukee  D000250     33.28.138.82       M028
# 37           Debit       San Jose  D000448    73.108.76.238       M074
# 38           Debit           Mesa  D000077     49.29.37.185       M048
# 39           Debit  Oklahoma City  D000038    49.20.211.229       M040
# 40           Debit    San Antonio  D000557     6.234.101.35       M014
# 41           Debit   Philadelphia  D000627  109.105.179.186       M046
# 42          Credit      Charlotte  D000198    60.89.202.192       M044
# 43           Debit         Tucson  D000197   173.135.78.201       M009
# 44           Debit     Louisville  D000685   77.208.193.198       M005
# 45           Debit        Chicago  D000297   197.162.55.147       M051
# 46           Debit      Baltimore  D000103   113.115.81.178       M070
# 47           Debit  Oklahoma City  D000397    186.135.2.148       M090
# 48           Debit         Denver  D000284    93.146.251.20       M023
# 49          Credit     Sacramento      NaN     124.6.134.78       M055
#
#    Channel CustomerOccupation  TransactionDuration  LoginAttempts  \
# 0      ATM             Doctor                 81.0            1.0
# 1      ATM             Doctor                141.0            1.0
# 2   Online            Student                 56.0            1.0
# 3   Online            Student                 25.0            1.0
# 4   Online            Student                198.0            1.0
# 5      ATM            Student                172.0            1.0
# 6      ATM             Doctor                139.0            1.0
# 7   Branch            Retired                291.0            1.0
# 8   Branch           Engineer                 86.0            1.0
# 9      ATM             Doctor                120.0            1.0
# 10  Online           Engineer                 59.0            1.0
# 11  Online            Student                173.0            1.0
# 12  Branch            Student                111.0            1.0
# 13     ATM            Student                123.0            1.0
# 14  Online            Student                134.0            1.0
# 15     ATM           Engineer                129.0            1.0
# 16  Branch            Student                158.0            1.0
# 17  Online           Engineer                234.0            1.0
# 18  Branch            Retired                106.0            1.0
# 19  Online            Student                169.0            1.0
# 20  Branch            Retired                 38.0            1.0
# 21  Branch             Doctor                 93.0            1.0
# 22  Online           Engineer                120.0            1.0
# 23  Online            Student                142.0            3.0
# 24  Online            Student                 96.0            1.0
# 25  Online            Retired                276.0            1.0
# 26     ATM            Student                158.0            5.0
# 27  Branch           Engineer                 95.0            1.0
# 28  Online             Doctor                197.0            1.0
# 29  Branch            Student                283.0            1.0
# 30  Online             Doctor                 20.0            1.0
# 31     ATM             Doctor                257.0            1.0
# 32     ATM           Engineer                168.0            3.0
# 33  Online            Student                150.0            1.0
# 34  Branch             Doctor                 50.0            1.0
# 35  Branch           Engineer                 45.0            1.0
# 36  Branch            Student                145.0            1.0
# 43          241.79     2024-11-04 08:08:03  Young Adult       3
# 44          868.61     2024-11-04 08:09:53  Young Adult       2
# 45         4673.28     2024-11-04 08:11:12       Senior       1
# 46         1509.27     2024-11-04 08:10:33  Young Adult       2
# 47          781.70     2024-11-04 08:11:35  Young Adult       3
# 48          265.51     2024-11-04 08:07:24  Young Adult       2
# 49         1335.09     2024-11-04 08:06:31  Middle-Aged       3

# %% [markdown]
# # **3. Data Splitting**
# Tahap Data Splitting bertujuan untuk memisahkan dataset menjadi dua bagian: data latih (training set) dan data uji (test set).

# %%
# Menggunakan train_test_split() untuk melakukan pembagian dataset.
# Menggunakan train_test_split() untuk melakukan pembagian dataset.
X = df.drop('Target', axis=1)
y = df['Target']

# Mengubah fitur kategorikal menjadi numerik menggunakan one-hot encoding
X = pd.get_dummies(X, drop_first=True)

# Menggunakan train_test_split() untuk melakukan pembagian dataset.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print("Dimensi Data Latih (X_train):", X_train.shape)
print("Dimensi Data Uji (X_test):", X_test.shape)
print("\n" + "="*50 + "\n")
# Out:
# Dimensi Data Latih (X_train): (1759, 7242)
# Dimensi Data Uji (X_test): (754, 7242)
#
# ==================================================

# %% [markdown]
# # **4. Membangun Model Klasifikasi**
# Setelah memilih algoritma klasifikasi yang sesuai, langkah selanjutnya adalah melatih model menggunakan data latih.
#
# Berikut adalah rekomendasi tahapannya.
# 1. Menggunakan algoritma klasifikasi yaitu Decision Tree.
# 2. Latih model menggunakan data yang sudah dipisah.

# %%
# Buatlah model klasifikasi menggunakan Decision Tree
model_dt = DecisionTreeClassifier(random_state=42)

# Latih model
model_dt.fit(X_train, y_train)

# Evaluasi model Decision Tree
y_pred_dt = model_dt.predict(X_test)
print("Laporan Klasifikasi - Decision Tree (Baseline):")
print(classification_report(y_test, y_pred_dt))
# Out:
# Laporan Klasifikasi - Decision Tree (Baseline):
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       164
#            1       0.68      0.74      0.71       114
#            2       0.85      0.73      0.79       156
#            3       0.88      0.84      0.86       173
#            4       0.51      0.59      0.55       147
#
#     accuracy                           0.75       754
#    macro avg       0.76      0.75      0.75       754
# weighted avg       0.77      0.75      0.76       754

# %%
# Menyimpan Model
# import joblib
joblib.dump(model_dt, 'decision_tree_model.h5')
print("Model Decision Tree berhasil disimpan sebagai 'decision_tree_model.h5'")
print("\n" + "="*50 + "\n")
# Out:
# Model Decision Tree berhasil disimpan sebagai 'decision_tree_model.h5'
#
# ==================================================

# %% [markdown]
# # **5. Memenuhi Kriteria Skilled dan Advanced dalam Membangun Model Klasifikasi**

# %% [markdown]
# **Biarkan kosong jika tidak menerapkan kriteria skilled atau advanced**

# %%
# Melatih model menggunakan algoritma klasifikasi selain Decision Tree.

# Model 1: Random Forest
print("Melatih Model Random Forest...")
model_rf = RandomForestClassifier(random_state=42)
model_rf.fit(X_train, y_train)
y_pred_rf = model_rf.predict(X_test)

# Model 2: Logistic Regression
print("Melatih Model Logistic Regression...")
model_lr = LogisticRegression(random_state=42, max_iter=1000)
model_lr.fit(X_train, y_train)
y_pred_lr = model_lr.predict(X_test)
print("\n" + "="*50 + "\n")
# Out:
# Melatih Model Random Forest...
# Melatih Model Logistic Regression...
#
# ==================================================
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Menampilkan hasil evaluasi akurasi, presisi, recall, dan F1-Score pada seluruh algoritma yang sudah dibuat.
print("Laporan Klasifikasi - Random Forest:")
print(classification_report(y_test, y_pred_rf))

print("Laporan Klasifikasi - Logistic Regression:")
print(classification_report(y_test, y_pred_lr))
# Out:
# Laporan Klasifikasi - Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       164
#            1       0.75      0.81      0.78       114
#            2       0.96      0.67      0.79       156
#            3       0.91      0.80      0.86       173
#            4       0.56      0.77      0.65       147
#
#     accuracy                           0.79       754
#    macro avg       0.81      0.79      0.79       754
# weighted avg       0.82      0.79      0.79       754
#
# Laporan Klasifikasi - Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.48      0.82      0.60       164
#            1       0.88      0.12      0.22       114
#            2       0.68      0.65      0.66       156
#            3       0.70      0.61      0.65       173
#            4       0.45      0.47      0.46       147
#
#     accuracy                           0.56       754
#    macro avg       0.64      0.54      0.52       754
# weighted avg       0.62      0.56      0.54       754

# %%
# Menyimpan Model Selain Decision Tree
joblib.dump(model_rf, 'explore_RandomForest_classification.h5')
joblib.dump(model_lr, 'explore_LogisticRegression_classification.h5')
print("Model lain berhasil disimpan.")
print("\n" + "="*50 + "\n")
# Out:
# Model lain berhasil disimpan.
#
# ==================================================

# %% [markdown]
# Hyperparameter Tuning Model
#
# Pilih salah satu algoritma yang ingin Anda tuning

# %%
# Lakukan Hyperparameter Tuning dan Latih ulang.
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Lakukan Hyperparameter Tuning dan Latih ulang.
print("Memulai Hyperparameter Tuning untuk Decision Tree...")
grid_search = GridSearchCV(estimator=DecisionTreeClassifier(random_state=42),
                           param_grid=param_grid,
                           cv=5,
                           n_jobs=-1,
                           verbose=1,
                           scoring='accuracy')

grid_search.fit(X_train, y_train)

# Dapatkan model terbaik
best_dt = grid_search.best_estimator_

print("\nParameter terbaik ditemukan:", grid_search.best_params_)
print("\n" + "="*50 + "\n")
# Out:
# Memulai Hyperparameter Tuning untuk Decision Tree...
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
#
# Parameter terbaik ditemukan: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# ==================================================

# %%
# Menampilkan hasil evaluasi akurasi, presisi, recall, dan F1-Score pada algoritma yang sudah dituning.
y_pred_tuned_dt = best_dt.predict(X_test)
print("Laporan Klasifikasi - Decision Tree (Setelah Tuning):")
print(classification_report(y_test, y_pred_tuned_dt))
# Out:
# Laporan Klasifikasi - Decision Tree (Setelah Tuning):
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       164
#            1       0.65      0.65      0.65       114
#            2       0.82      0.71      0.76       156
#            3       0.88      0.84      0.86       173
#            4       0.45      0.54      0.50       147
#
#     accuracy                           0.73       754
#    macro avg       0.73      0.72      0.72       754
# weighted avg       0.74      0.73      0.73       754

# %%
# Menyimpan Model hasil tuning
joblib.dump(best_dt, 'tuning_classification.h5')
print("Model hasil tuning berhasil disimpan sebagai 'tuning_classification.h5'")
# Out:
# Model hasil tuning berhasil disimpan sebagai 'tuning_classification.h5'
